# %% [markdown]
# <a href="https://colab.research.google.com/github/dhkfkr134/algorithm/blob/main/python/string.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## String

# %% [markdown]
# ### baekjoon2743

# %%
S = input()
i = int(input())
print(S[i-1])

# %%
import sys
S = sys.stdin.readline()
i = int(sys.stdin.readline())
print(S[i-1])

# %% [markdown]
# ### baekjoon27866

# %%
str = input()
print(len(str))

# %% [markdown]
# ### baekjoon9086

# %%
T = int(input())
for i in range(T):
    str = input()
    print(str[0]+str[-1])

# %% [markdown]
# ### baekjoon11654
#
# ord(chr)
# chr(i)

# %%
c = input()
print(ord(c))

# %% [markdown]
# ### baekjoon11720

# %%
N = int(input())
str = input()
sum = 0
for s in str:
    sum += ord(s) - ord('0')
print(sum)

# %%
N = input()
N_l = list(map(int,input()))

print(sum(N_l))

# %% [markdown]
# ### baekjoon10809

# %%
S = input()
array = [-1] * 26
for i in range(len(S)):
    x = ord(S[i]) - ord('a')

    array[x] = i if array[x] == -1 else array[x]

for arr in array:
    print(arr, end =" ")
